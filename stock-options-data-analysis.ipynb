# %% [markdown]
# # Stock Options Data Analysis Using Python and YahooQuery

# %%
# Install the necessary packages, if needed
#!pip install yahooquery
#!pip install pandas

# Import necessary packages
from yahooquery import Ticker
from datetime import datetime
import pandas as pd

# %% [markdown]
# #### Create a 'Ticker' object from the yahooquery library

# %%
symbol = "PFE"
myTicker = Ticker(symbol)
print(myTicker)
print(type(myTicker))
# Out:
# <yahooquery.ticker.Ticker object at 0x0000022CD708BE00>
# <class 'yahooquery.ticker.Ticker'>

# %% [markdown]
# #### Pull all available options data from the library and put it in a dataframe

# %%
df = myTicker.option_chain.reset_index()
print(df.info())
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 595 entries, 0 to 594
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symbol             595 non-null    object
#  1   expiration         595 non-null    datetime64[ns]
#  2   optionType         595 non-null    object
#  3   contractSymbol     595 non-null    object
#  4   strike             595 non-null    float64
#  5   currency           595 non-null    object
#  6   lastPrice          595 non-null    float64
#  7   change             595 non-null    float64
#  8   percentChange      595 non-null    float64
#  9   openInterest       595 non-null    int64
#  10  bid                595 non-null    float64
#  11  ask                595 non-null    float64
#  12  contractSize       595 non-null    object
#  13  lastTradeDate      595 non-null    datetime64[ns]
#  14  impliedVolatility  595 non-null    float64
#  15  inTheMoney         595 non-null    bool
#  16  volume             595 non-null    float64
# dtypes: bool(1), datetime64[ns](2), float64(8), int64(1), object(5)
# memory usage: 75.1+ KB
# None
#     symbol expiration optionType      contractSymbol  strike currency  \
# 0      PFE 2025-10-03      calls  PFE251003C00015000    15.0      USD
# 1      PFE 2025-10-03      calls  PFE251003C00018000    18.0      USD
# 2      PFE 2025-10-03      calls  PFE251003C00019000    19.0      USD
# 3      PFE 2025-10-03      calls  PFE251003C00019500    19.5      USD
# 4      PFE 2025-10-03      calls  PFE251003C00020000    20.0      USD
# ..     ...        ...        ...                 ...     ...      ...
# 590    PFE 2028-01-21       puts  PFE280121P00025000    25.0      USD
# 591    PFE 2028-01-21       puts  PFE280121P00027000    27.0      USD
# 592    PFE 2028-01-21       puts  PFE280121P00030000    30.0      USD
# 593    PFE 2028-01-21       puts  PFE280121P00032000    32.0      USD
# 594    PFE 2028-01-21       puts  PFE280121P00035000    35.0      USD
#
#      lastPrice  change  percentChange  openInterest    bid    ask  \
# 0         9.70    0.00       0.000000             2   8.65   8.85
# 1         5.68    0.00       0.000000             2   5.75   5.85
# 2         4.80    0.00       0.000000             6   4.80   4.85
# 3         4.85    0.00       0.000000            34   4.25   4.35
# 4         3.70    0.00       0.000000            58   3.75   3.85
# ..         ...     ...            ...           ...    ...    ...
# 590       5.00    0.00       0.000000           769   4.85   5.10
# 591       6.35    0.03       0.474679           443   6.25   6.40
# 592       8.30    0.00       0.000000            39   8.40   8.75
# 593      10.00    0.00       0.000000            74   9.95  11.50
# 594      12.82    0.00       0.000000            40  12.40  12.75
#
#     contractSize       lastTradeDate  impliedVolatility  inTheMoney  volume
# 0        REGULAR 2025-08-28 15:14:45           2.031255        True     0.0
# 1        REGULAR 2025-09-26 15:07:13           1.320316        True     1.0
# 2        REGULAR 2025-09-25 17:48:12           0.953125        True     1.0
# 3        REGULAR 2025-09-17 14:00:04           0.996094        True     0.0
# 4        REGULAR 2025-09-26 17:25:14           0.890626        True     1.0
# ..           ...                 ...                ...         ...     ...
# 590      REGULAR 2025-09-26 19:48:55           0.305305        True   296.0
# 591      REGULAR 2025-09-29 13:44:24           0.303474        True    25.0
# 592      REGULAR 2025-09-24 17:01:12           0.314582        True    19.0
# 593      REGULAR 2025-09-25 14:11:10           0.399542        True    30.0
# 594      REGULAR 2025-09-25 19:49:36           0.310065        True    10.0
#
# [595 rows x 17 columns]

# %% [markdown]
# ### Let's choose a target expiration date to analyze.
# #### Most options contracts close on Friday. Let's choose Friday Oct 31.

# %%
exp_date = datetime(2025, 10, 31).strftime('%Y-%m-%d')
df[df['expiration'] == exp_date]
# Out:
#     symbol expiration optionType      contractSymbol  strike currency  \
# 195    PFE 2025-10-31      calls  PFE251031C00020000    20.0      USD
# 196    PFE 2025-10-31      calls  PFE251031C00021000    21.0      USD
# 197    PFE 2025-10-31      calls  PFE251031C00021500    21.5      USD
# 198    PFE 2025-10-31      calls  PFE251031C00022000    22.0      USD
# 199    PFE 2025-10-31      calls  PFE251031C00022500    22.5      USD
# 200    PFE 2025-10-31      calls  PFE251031C00023000    23.0      USD
# 201    PFE 2025-10-31      calls  PFE251031C00023500    23.5      USD
# 202    PFE 2025-10-31      calls  PFE251031C00024000    24.0      USD
# 203    PFE 2025-10-31      calls  PFE251031C00024500    24.5      USD
# 204    PFE 2025-10-31      calls  PFE251031C00025000    25.0      USD
# 205    PFE 2025-10-31      calls  PFE251031C00025500    25.5      USD
# 206    PFE 2025-10-31      calls  PFE251031C00026000    26.0      USD
# 207    PFE 2025-10-31      calls  PFE251031C00026500    26.5      USD
# 208    PFE 2025-10-31      calls  PFE251031C00027000    27.0      USD
# 209    PFE 2025-10-31      calls  PFE251031C00027500    27.5      USD
# 210    PFE 2025-10-31      calls  PFE251031C00028000    28.0      USD
# 211    PFE 2025-10-31      calls  PFE251031C00028500    28.5      USD
# 212    PFE 2025-10-31      calls  PFE251031C00029000    29.0      USD
# 213    PFE 2025-10-31      calls  PFE251031C00030000    30.0      USD
# 214    PFE 2025-10-31      calls  PFE251031C00035000    35.0      USD
# 215    PFE 2025-10-31       puts  PFE251031P00020000    20.0      USD
# 216    PFE 2025-10-31       puts  PFE251031P00020500    20.5      USD
# 217    PFE 2025-10-31       puts  PFE251031P00021000    21.0      USD
# 218    PFE 2025-10-31       puts  PFE251031P00021500    21.5      USD
# 219    PFE 2025-10-31       puts  PFE251031P00022000    22.0      USD
# 220    PFE 2025-10-31       puts  PFE251031P00022500    22.5      USD
# 221    PFE 2025-10-31       puts  PFE251031P00023000    23.0      USD
# 222    PFE 2025-10-31       puts  PFE251031P00023500    23.5      USD
# 223    PFE 2025-10-31       puts  PFE251031P00024000    24.0      USD
# 224    PFE 2025-10-31       puts  PFE251031P00024500    24.5      USD
# 225    PFE 2025-10-31       puts  PFE251031P00025000    25.0      USD
# 226    PFE 2025-10-31       puts  PFE251031P00025500    25.5      USD
# 227    PFE 2025-10-31       puts  PFE251031P00026000    26.0      USD
# 228    PFE 2025-10-31       puts  PFE251031P00026500    26.5      USD
#
#      lastPrice  change  percentChange  openInterest   bid   ask contractSize  \
# 195       4.30    0.00       0.000000            50  3.85  3.95      REGULAR
# 196       3.28    0.00       0.000000            10  2.88  2.97      REGULAR
# 197       2.60    0.00       0.000000             1  2.44  2.51      REGULAR
# 198       1.89    0.00       0.000000            16  1.98  2.03      REGULAR
# 199       1.51    0.00       0.000000            82  1.56  1.60      REGULAR
# 200       1.14    0.00       0.000000           221  1.16  1.25      REGULAR
# 201       0.80    0.00       0.000000           147  0.84  0.87      REGULAR
# 202       0.60    0.03       5.263164          1628  0.57  0.60      REGULAR
# 203       0.39    0.00       0.000000          2747  0.37  0.40      REGULAR
# 204       0.24    0.00       0.000000          3742  0.23  0.25      REGULAR
# 205       0.14   -0.02     -12.499997          1152  0.14  0.17      REGULAR
# 206       0.10    0.00       0.000000          1743  0.09  0.11      REGULAR
# 207       0.06   -0.01     -14.285716           579  0.05  0.08      REGULAR
# 208       0.07    0.00       0.000000           812  0.03  0.05      REGULAR
# 209       0.09    0.00       0.000000           197  0.02  0.05      REGULAR
# 210       0.06    0.00       0.000000           286  0.02  0.06      REGULAR
# 211       0.05    0.00       0.000000             2  0.00  0.07      REGULAR
# 212       0.02    0.00       0.000000            39  0.00  0.07      REGULAR
# 213       0.02    0.00       0.000000             1  0.00  0.06      REGULAR
# 214       0.03    0.00       0.000000           100  0.00  0.02      REGULAR
# 215       0.04    0.00       0.000000            33  0.01  0.04      REGULAR
# 216       0.09    0.00       0.000000             1  0.00  0.06      REGULAR
# 217       0.05    0.00       0.000000            74  0.00  0.06      REGULAR
# 218       0.11    0.00       0.000000            91  0.06  0.08      REGULAR
# 219       0.14    0.02      16.666670           170  0.11  0.13      REGULAR
# 220       0.22    0.01       4.761907           240  0.17  0.20      REGULAR
# 221       0.30   -0.02      -5.882348           651  0.28  0.32      REGULAR
# 222       0.45   -0.05     -10.000002          1058  0.45  0.48      REGULAR
# 223       0.75    0.00       0.000000          5572  0.68  0.71      REGULAR
# 224       1.08    0.00       0.000000           281  0.98  1.01      REGULAR
# 225       1.39   -0.04      -2.797200            71  1.34  1.39      REGULAR
# 226       1.90    0.00       0.000000           159  1.76  1.84      REGULAR
# 227       2.47    0.00       0.000000            17  2.22  2.55      REGULAR
# 228       2.53    0.00       0.000000             2  2.69  2.97      REGULAR
#
#           lastTradeDate  impliedVolatility  inTheMoney  volume
# 195 2025-09-23 14:07:14           0.456060        True     0.0
# 196 2025-09-23 13:39:47           0.372077        True     1.0
# 197 2025-09-15 16:25:53           0.346686        True     0.0
# 198 2025-09-26 16:01:59           0.303718        True     1.0
# 199 2025-09-26 15:31:10           0.281257        True    50.0
# 200 2025-09-26 16:33:09           0.278816        True     4.0
# 201 2025-09-26 18:21:58           0.249031        True    65.0
# 202 2025-09-29 14:11:17           0.241707       False   125.0
# 203 2025-09-29 13:30:14           0.239265       False    48.0
# 204 2025-09-29 14:07:06           0.235359       False   128.0
# 205 2025-09-29 13:30:08           0.244148       False    14.0
# 206 2025-09-29 14:15:51           0.250007       False    88.0
# 207 2025-09-29 13:32:55           0.263679       False     4.0
# 208 2025-09-26 18:03:38           0.265632       False     3.0
# 209 2025-09-23 13:38:36           0.294929       False     5.0
# 210 2025-09-25 14:13:22           0.335944       False     2.0
# 211 2025-09-22 15:18:10           0.376959       False     1.0
# 212 2025-09-24 14:15:30           0.404303       False     0.0
# 213 2025-09-17 19:39:15           0.443365       False     0.0
# 214 2025-09-23 13:30:03           0.515630       False     0.0
# 215 2025-09-25 16:43:31           0.339850       False   100.0
# 216 2025-09-12 19:23:37           0.326179       False     0.0
# 217 2025-09-26 14:19:40           0.283210       False    30.0
# 218 2025-09-25 19:59:34           0.259773       False    30.0
# 219 2025-09-29 13:39:31           0.250007       False     5.0
# 220 2025-09-29 13:44:04           0.236336       False     4.0
# 221 2025-09-29 14:13:04           0.229500       False    92.0
# 222 2025-09-29 14:11:31           0.218758       False    27.0
# 223 2025-09-26 19:53:27           0.211922        True    32.0
# 224 2025-09-26 19:56:50           0.207039        True     1.0
# 225 2025-09-29 13:30:04           0.210945        True     1.0
# 226 2025-09-26 15:18:36           0.230476        True     1.0
# 227 2025-09-26 15:09:18           0.378912        True     1.0
# 228 2025-09-16 15:01:57           0.383795        True     1.0

# %% [markdown]
# ### That's still too many to think about. Let's narrow it down.
# #### The main variables when buying/selling options are:
# * Action (Sell to Open / Buy To Close for writes; Buy to Open / Sell to Close for buys)
# * Quantity of Contracts
# * Company Symbol
# * Expiration Date
# * Contract Type (Put or Call)
# * Strike Price (execution price)
# * Premium (revenue gained)
#
# #### So an options contract might read:
# #### Sell To Open 10 PFE Oct 31 2025 \$23.00 PUT
# * This means: sell to open 10 contracts, representing the obligation to purchase 1,000 shares of PFE stock on Oct 31, 2025, for \$23,000
# * If PFE is at or above \$23 per share on Oct 31, the option will expire worthless and the put writer keeps the premium
# * If PFE is below \$23 per share on Oct 31, the put writer will be forced to buy the shares for more than the market value
# * For example, if PFE is trading at 22 per share on Oct 31, the put writer has an immediate, unrealized loss (on paper) of \$1,000 on the shares

# %% [markdown]
# # Putting it all together

# %% [markdown]
# ### Create filtered options dataframe based on user inputs

# %%
# Create filtered options dataframe based on user inputs
def filtered_options_df(mySymbol, myType, strikeLo, strikeHi, myExp):
    
    # Put all options data into a dataframe
    myTicker = Ticker(mySymbol)
    df = myTicker.option_chain.reset_index()

    filtered_df = df[
        (df['optionType'] == myType) &
        (df['strike'] >= strikeLo) &
        (df['strike'] <= strikeHi) &
        (df['expiration'] == myExp)]
    return filtered_df

filtered_options_df("PFE", "puts", 23, 23, datetime(2025, 10, 31).strftime('%Y-%m-%d'))
# Out:
#     symbol expiration optionType      contractSymbol  strike currency  \
# 221    PFE 2025-10-31       puts  PFE251031P00023000    23.0      USD
#
#      lastPrice  change  percentChange  openInterest   bid   ask contractSize  \
# 221        0.3   -0.02      -5.882348           651  0.28  0.32      REGULAR
#
#           lastTradeDate  impliedVolatility  inTheMoney  volume
# 221 2025-09-29 14:13:04             0.2295       False    92.0

# %% [markdown]
# ### Now we can observe key data about the contract:
# * The bid/ask spread (premium amount) on the contract
# * Implied Volatility
# * Open interest (number of contracts open)
# * Last Price, Volume, if it's In the Money, etc

# %% [markdown]
# ### If we want to change the range of strikes to see the entire chain for a given date, it's easy

# %%
filtered_options_df("PFE", "puts", 21, 25, datetime(2025, 10, 31).strftime('%Y-%m-%d'))
# Out:
#     symbol expiration optionType      contractSymbol  strike currency  \
# 217    PFE 2025-10-31       puts  PFE251031P00021000    21.0      USD
# 218    PFE 2025-10-31       puts  PFE251031P00021500    21.5      USD
# 219    PFE 2025-10-31       puts  PFE251031P00022000    22.0      USD
# 220    PFE 2025-10-31       puts  PFE251031P00022500    22.5      USD
# 221    PFE 2025-10-31       puts  PFE251031P00023000    23.0      USD
# 222    PFE 2025-10-31       puts  PFE251031P00023500    23.5      USD
# 223    PFE 2025-10-31       puts  PFE251031P00024000    24.0      USD
# 224    PFE 2025-10-31       puts  PFE251031P00024500    24.5      USD
# 225    PFE 2025-10-31       puts  PFE251031P00025000    25.0      USD
#
#      lastPrice  change  percentChange  openInterest   bid   ask contractSize  \
# 217       0.05    0.00       0.000000            74  0.00  0.06      REGULAR
# 218       0.11    0.00       0.000000            91  0.06  0.08      REGULAR
# 219       0.14    0.02      16.666670           170  0.11  0.13      REGULAR
# 220       0.22    0.01       4.761907           240  0.17  0.20      REGULAR
# 221       0.30   -0.02      -5.882348           651  0.28  0.32      REGULAR
# 222       0.45   -0.05     -10.000002          1058  0.45  0.48      REGULAR
# 223       0.75    0.00       0.000000          5572  0.68  0.71      REGULAR
# 224       1.08    0.00       0.000000           281  0.98  1.01      REGULAR
# 225       1.39   -0.04      -2.797200            71  1.34  1.39      REGULAR
#
#           lastTradeDate  impliedVolatility  inTheMoney  volume
# 217 2025-09-26 14:19:40           0.283210       False    30.0
# 218 2025-09-25 19:59:34           0.259773       False    30.0
# 219 2025-09-29 13:39:31           0.250007       False     5.0
# 220 2025-09-29 13:44:04           0.236336       False     4.0
# 221 2025-09-29 14:13:04           0.229500       False    92.0
# 222 2025-09-29 14:11:31           0.218758       False    27.0
# 223 2025-09-26 19:53:27           0.211922        True    32.0
# 224 2025-09-26 19:56:50           0.207039        True     1.0
# 225 2025-09-29 13:30:04           0.210945        True     1.0

# %% [markdown]
# # Let's use the Expected Move Formula to Predict Stock Prices on a Given Date

# %% [markdown]
# # $$ \text{Expected Move} = P \times \text{IV} \times \sqrt{\frac{D}{365}} $$
# #### Where P = Current Market Price, IV = Implied Volatility, D = Numer of Days until Expiration Date
#
# * This formula tells us how far up or down the price is 'expected' to move.
# * The inputs are the stock's implied volatility, current price, and time to expiration
# * For example if market price is 100 and the expected move is 5, we would expect the stock to be between 95 and 105 at the expiration date

# %% [markdown]
# ## Crucially, IV must be taken from an At-The-Money Put or Call
# #### Let's find the current market price
# #### For a deeper dive on that, check my previous tutorial: [How to Fetch Stock Data](https://github.com/yusifrefae/Jupyter-Projects/blob/main/fetch-stock-data.ipynb)

# %%
import yfinance as yf

symbol = "PFE"
mkt_price =  yf.Ticker(symbol).info.get('currentPrice')
print(f"Market Price: {mkt_price:.2f}")

# Round the price
rounded_price = round(mkt_price)
print(f"Rounded Price: {rounded_price:.2f}")
# Out:
# Market Price: 23.81
# Rounded Price: 24.00

# %% [markdown]
# ### Let's examine the at-the-money put and reset the index to 0

# %%
atm_put = filtered_options_df("PFE", "puts", rounded_price, rounded_price, 
                              datetime(2025, 10, 31).strftime('%Y-%m-%d')).reset_index()
atm_put
# Out:
#    index symbol expiration optionType      contractSymbol  strike currency  \
# 0    223    PFE 2025-10-31       puts  PFE251031P00024000    24.0      USD
#
#    lastPrice  change  percentChange  openInterest   bid   ask contractSize  \
# 0       0.75     0.0            0.0          5572  0.68  0.71      REGULAR
#
#         lastTradeDate  impliedVolatility  inTheMoney  volume
# 0 2025-09-26 19:53:27           0.211922        True    32.0

# %% [markdown]
# ### Let's take the IV value from the single row of data

# %%
iv = atm_put.loc[0, 'impliedVolatility']
iv
# Out:
# np.float64(0.21192194335937498)

# %% [markdown]
# ### Finally, let's calculate the number of days between now and expiration

# %%
# Subtract today's timestamp value from ATM option's expiration date
days = atm_put.loc[0, 'expiration'] - pd.Timestamp.now()

# Convert timestamp to more usable float data
days = days.total_seconds() / (24 * 60 * 60)
days
# Out:
# 31.254836732835646

# %% [markdown]
# ### We now have all the inputs to our formula

# %% [raw]
# print(f"Current Market Price: ${rounded_price:.2f}")
# print(f"Implied Volatility: {iv*100:.2f}%")
# print(f"Days to Expiration: {days:.1f}")

# %%
import numpy as np

# Calculate expected move of the stock 
expected_move = rounded_price * iv * np.sqrt(days/365)
print(f"Expected Move: ${expected_move:.2f}")
print(f"Expected Range: ${rounded_price - expected_move:.2f} - ${rounded_price + expected_move:.2f}")
# Out:
# Expected Move: $1.49
# Expected Range: $22.51 - $25.49

# %% [markdown]
# ### Interpretation: On Oct 31 we expect the price to be between 22.23 and 25.29 per share
# * The expected move is 1.53 from the current price
# * Our strike of 23 is in the range of the expected move
# * So we might want to adjust the strike for our put sale down to 22 per share

# %% [markdown]
# # There's so much more you can do with this data!
# # This is just the tip of the iceberg!
